# %% [markdown]
# # Task 1: Pre-processing the data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df=pd.read_csv(r"C:\Users\Mayank PC\Downloads\weather_dataset_stage1.xls - Sheet 1 - weather_dataset (1).csv")

# %%
df
# Out:
#              Date  Temperature  Average humidity (%  Average dewpoint (°F  \
# 0      01-01-2022       '37.8'               '35.0'                '12.7'
# 1     2022-01-02'       '43.2'               '32.0'                '14.7'
# 2     2022-01-03'       '25.7'               '60.0'                '12.7'
# 3     2022-01-04'        '9.3'               '67.0'                 '0.1'
# 4     2022-01-05'       '23.5'               '30.0'                '-5.3'
# ...           ...          ...                  ...                   ...
# 3898  2022-07-25'       '62.8'               '60.0'                '48.1'
# 3899  2022-07-26'       '60.6'               '68.0'                '48.9'
# 3900  2022-07-27'       '61.7'               '64.0'                '47.4'
# 3901  2022-07-28'       '60.5'               '61.0'                '45.3'
# 3902  2022-07-28'       '60.5'               '61.0'                '45.3'
#
#       Average barometer (in  Average windspeed (mph  Average gustspeed (mph  \
# 0                    '29.7'                  '26.4'                  '36.8'
# 1                    '29.5'                  '12.8'                  '18.0'
# 2                    '29.7'                   '8.3'                  '12.2'
# 3                    '30.4'                   '2.9'                   '4.5'
# 4                    '29.9'                  '16.7'                  '23.1'
# ...                     ...                     ...                     ...
# 3898                 '29.7'                   '2.5'                   '4.0'
# 3899                 '29.8'                   '1.7'                   '2.9'
# 3900                 '29.9'                   '2.2'                   '4.0'
# 3901                 '29.7'                   '4.0'                   '6.2'
# 3902                 '29.7'                   '4.0'                   '6.2'
#
#       Average direction (°deg  Rainfall for month (in Rainfall for year (in  \
# 0                     '274.0'                   '0.0'                 '0.0'
# 1                     '240.0'                   '0.0'                 '0.0'
# 2                     '290.0'                   '0.0'                 '0.0'
# 3                      '47.0'                   '0.0'                 '0.0'
# 4                     '265.0'                   '0.0'                 '0.0'
# ...                       ...                     ...                   ...
# 3898                  '242.0'                  '0.33'                '4.47'
# 3899                  '357.0'                  '0.33'                '4.47'
# 3900                   '66.0'                  '0.33'                '4.47'
# 3901                  '248.0'                  '0.35'                '4.49'
# 3902                  '248.0'                  '0.35'                '4.49'
#
#       ...  Maximum humidity (%  Minimum humidity (%  Maximum pressure  \
# 0     ...                '4.0'               '27.0'          '29.762'
# 1     ...                '4.0'               '16.0'          '29.669'
# 2     ...                '8.0'               '35.0'          '30.232'
# 3     ...                '7.0'               '35.0'          '30.566'
# 4     ...                '5.0'               '13.0'          '30.233'
# ...   ...                  ...                  ...               ...
# 3898  ...               '90.0'               '36.0'          '29.781'
# 3899  ...               '90.0'               '40.0'           '29.93'
# 3900  ...               '96.0'               '35.0'          '29.941'
# 3901  ...               '94.0'               '35.0'          '29.792'
# 3902  ...               '94.0'               '35.0'          '29.792'
#
#       Minimum pressure  Maximum windspeed (mph  Maximum gust speed (mph  \
# 0             '29.596'                  '41.4'                   '59.0'
# 1             '29.268'                  '35.7'                   '51.0'
# 2              '29.26'                  '25.3'                   '38.0'
# 3             '30.227'                  '12.7'                   '20.0'
# 4             '29.568'                  '38.0'                   '53.0'
# ...                ...                     ...                      ...
# 3898          '29.645'                   '8.1'                   '17.3'
# 3899          '29.745'                  '11.5'                   '15.0'
# 3900          '29.781'                  '13.8'                   '18.4'
# 3901          '29.675'                  '17.3'                   '26.5'
# 3902          '29.675'                  '17.3'                   '26.5'
#
#       Maximum heat index (°F         Date1  Month           diff_pressure
# 0                     '40.0'  '2022-01-01'   '01'   '0.16600000000000037'
# 1                     '52.0'  '2022-01-02'   '01'    '0.4009999999999998'
# 2                     '41.0'  '2022-01-03'   '01'    '0.9719999999999978'
# 3                     '32.0'  '2022-01-04'   '01'   '0.33899999999999864'
# 4                     '32.0'  '2022-01-05'   '01'    '0.6649999999999991'
# ...                      ...           ...    ...                     ...
# 3898                  '77.5'  '2022-07-25'   '07'   '0.13599999999999923'
# 3899                  '77.5'  '2022-07-26'   '07'   '0.18499999999999872'
# 3900                  '78.2'  '2022-07-27'   '07'   '0.16000000000000014'
# 3901                  '77.6'  '2022-07-28'   '07'  '0.11700000000000088';
# 3902                  '77.6'  '2022-07-28'   '07'  '0.11700000000000088';
#
# [3903 rows x 23 columns]

# %%
df.isna().sum()
# Out:
# Date                        0
#  Temperature                0
#  Average humidity (%        0
#  Average dewpoint (°F       0
#  Average barometer (in      0
#  Average windspeed (mph     0
#  Average gustspeed (mph     0
#  Average direction (°deg    0
#  Rainfall for month (in     0
# Rainfall for year (in       0
#  Maximum rain per minute    0
#  Maximum temperature (°F    0
#  Minimum temperature (°F    0
#  Maximum humidity (%        0
#  Minimum humidity (%        0
#  Maximum pressure           0
#  Minimum pressure           0
#  Maximum windspeed (mph     0
#  Maximum gust speed (mph    0
#  Maximum heat index (°F     0
# Date1                       0
#  Month                      0
#  diff_pressure              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', ' Temperature', ' Average humidity (%', ' Average dewpoint (°F',
#        ' Average barometer (in', ' Average windspeed (mph',
#        ' Average gustspeed (mph', ' Average direction (°deg',
#        ' Rainfall for month (in', 'Rainfall for year (in',
#        ' Maximum rain per minute', ' Maximum temperature (°F',
#        ' Minimum temperature (°F', ' Maximum humidity (%',
#        ' Minimum humidity (%', ' Maximum pressure', ' Minimum pressure',
#        ' Maximum windspeed (mph', ' Maximum gust speed (mph',
#        ' Maximum heat index (°F', 'Date1', ' Month', ' diff_pressure'],
#       dtype='object')

# %%
col=['Date', ' Temperature', ' Average humidity (%', ' Average dewpoint (°F',
       ' Average barometer (in', ' Average windspeed (mph',
       ' Average gustspeed (mph', ' Average direction (°deg',
       ' Rainfall for month (in', 'Rainfall for year (in',
       ' Maximum rain per minute', ' Maximum temperature (°F',
       ' Minimum temperature (°F', ' Maximum humidity (%',
       ' Minimum humidity (%', ' Maximum pressure', ' Minimum pressure',
       ' Maximum windspeed (mph', ' Maximum gust speed (mph',
       ' Maximum heat index (°F', 'Date1', ' Month', ' diff_pressure']

# %%
for i in col:
    df[i]=df[i].str.replace("'",'')

# %%
df
# Out:
#             Date  Temperature  Average humidity (%  Average dewpoint (°F  \
# 0     01-01-2022         37.8                 35.0                  12.7
# 1     2022-01-02         43.2                 32.0                  14.7
# 2     2022-01-03         25.7                 60.0                  12.7
# 3     2022-01-04          9.3                 67.0                   0.1
# 4     2022-01-05         23.5                 30.0                  -5.3
# ...          ...          ...                  ...                   ...
# 3898  2022-07-25         62.8                 60.0                  48.1
# 3899  2022-07-26         60.6                 68.0                  48.9
# 3900  2022-07-27         61.7                 64.0                  47.4
# 3901  2022-07-28         60.5                 61.0                  45.3
# 3902  2022-07-28         60.5                 61.0                  45.3
#
#       Average barometer (in  Average windspeed (mph  Average gustspeed (mph  \
# 0                      29.7                    26.4                    36.8
# 1                      29.5                    12.8                    18.0
# 2                      29.7                     8.3                    12.2
# 3                      30.4                     2.9                     4.5
# 4                      29.9                    16.7                    23.1
# ...                     ...                     ...                     ...
# 3898                   29.7                     2.5                     4.0
# 3899                   29.8                     1.7                     2.9
# 3900                   29.9                     2.2                     4.0
# 3901                   29.7                     4.0                     6.2
# 3902                   29.7                     4.0                     6.2
#
#       Average direction (°deg  Rainfall for month (in Rainfall for year (in  \
# 0                       274.0                     0.0                   0.0
# 1                       240.0                     0.0                   0.0
# 2                       290.0                     0.0                   0.0
# 3                        47.0                     0.0                   0.0
# 4                       265.0                     0.0                   0.0
# ...                       ...                     ...                   ...
# 3898                    242.0                    0.33                  4.47
# 3899                    357.0                    0.33                  4.47
# 3900                     66.0                    0.33                  4.47
# 3901                    248.0                    0.35                  4.49
# 3902                    248.0                    0.35                  4.49
#
#       ...  Maximum humidity (%  Minimum humidity (%  Maximum pressure  \
# 0     ...                  4.0                 27.0            29.762
# 1     ...                  4.0                 16.0            29.669
# 2     ...                  8.0                 35.0            30.232
# 3     ...                  7.0                 35.0            30.566
# 4     ...                  5.0                 13.0            30.233
# ...   ...                  ...                  ...               ...
# 3898  ...                 90.0                 36.0            29.781
# 3899  ...                 90.0                 40.0             29.93
# 3900  ...                 96.0                 35.0            29.941
# 3901  ...                 94.0                 35.0            29.792
# 3902  ...                 94.0                 35.0            29.792
#
#       Minimum pressure  Maximum windspeed (mph  Maximum gust speed (mph  \
# 0               29.596                    41.4                     59.0
# 1               29.268                    35.7                     51.0
# 2                29.26                    25.3                     38.0
# 3               30.227                    12.7                     20.0
# 4               29.568                    38.0                     53.0
# ...                ...                     ...                      ...
# 3898            29.645                     8.1                     17.3
# 3899            29.745                    11.5                     15.0
# 3900            29.781                    13.8                     18.4
# 3901            29.675                    17.3                     26.5
# 3902            29.675                    17.3                     26.5
#
#       Maximum heat index (°F       Date1  Month         diff_pressure
# 0                       40.0  2022-01-01     01   0.16600000000000037
# 1                       52.0  2022-01-02     01    0.4009999999999998
# 2                       41.0  2022-01-03     01    0.9719999999999978
# 3                       32.0  2022-01-04     01   0.33899999999999864
# 4                       32.0  2022-01-05     01    0.6649999999999991
# ...                      ...         ...    ...                   ...
# 3898                    77.5  2022-07-25     07   0.13599999999999923
# 3899                    77.5  2022-07-26     07   0.18499999999999872
# 3900                    78.2  2022-07-27     07   0.16000000000000014
# 3901                    77.6  2022-07-28     07  0.11700000000000088;
# 3902                    77.6  2022-07-28     07  0.11700000000000088;
#
# [3903 rows x 23 columns]

# %%
df.dtypes
# Out:
# Date                        object
#  Temperature                object
#  Average humidity (%        object
#  Average dewpoint (°F       object
#  Average barometer (in      object
#  Average windspeed (mph     object
#  Average gustspeed (mph     object
#  Average direction (°deg    object
#  Rainfall for month (in     object
# Rainfall for year (in       object
#  Maximum rain per minute    object
#  Maximum temperature (°F    object
#  Minimum temperature (°F    object
#  Maximum humidity (%        object
#  Minimum humidity (%        object
#  Maximum pressure           object
#  Minimum pressure           object
#  Maximum windspeed (mph     object
#  Maximum gust speed (mph    object
#  Maximum heat index (°F     object
# Date1                       object
#  Month                      object
#  diff_pressure              object
# dtype: object

# %%
df
# Out:
#             Date  Temperature  Average humidity (%  Average dewpoint (°F  \
# 0     01-01-2022         37.8                 35.0                  12.7
# 1     2022-01-02         43.2                 32.0                  14.7
# 2     2022-01-03         25.7                 60.0                  12.7
# 3     2022-01-04          9.3                 67.0                   0.1
# 4     2022-01-05         23.5                 30.0                  -5.3
# ...          ...          ...                  ...                   ...
# 3898  2022-07-25         62.8                 60.0                  48.1
# 3899  2022-07-26         60.6                 68.0                  48.9
# 3900  2022-07-27         61.7                 64.0                  47.4
# 3901  2022-07-28         60.5                 61.0                  45.3
# 3902  2022-07-28         60.5                 61.0                  45.3
#
#       Average barometer (in  Average windspeed (mph  Average gustspeed (mph  \
# 0                      29.7                    26.4                    36.8
# 1                      29.5                    12.8                    18.0
# 2                      29.7                     8.3                    12.2
# 3                      30.4                     2.9                     4.5
# 4                      29.9                    16.7                    23.1
# ...                     ...                     ...                     ...
# 3898                   29.7                     2.5                     4.0
# 3899                   29.8                     1.7                     2.9
# 3900                   29.9                     2.2                     4.0
# 3901                   29.7                     4.0                     6.2
# 3902                   29.7                     4.0                     6.2
#
#       Average direction (°deg  Rainfall for month (in Rainfall for year (in  \
# 0                       274.0                     0.0                   0.0
# 1                       240.0                     0.0                   0.0
# 2                       290.0                     0.0                   0.0
# 3                        47.0                     0.0                   0.0
# 4                       265.0                     0.0                   0.0
# ...                       ...                     ...                   ...
# 3898                    242.0                    0.33                  4.47
# 3899                    357.0                    0.33                  4.47
# 3900                     66.0                    0.33                  4.47
# 3901                    248.0                    0.35                  4.49
# 3902                    248.0                    0.35                  4.49
#
#       ...  Maximum humidity (%  Minimum humidity (%  Maximum pressure  \
# 0     ...                  4.0                 27.0            29.762
# 1     ...                  4.0                 16.0            29.669
# 2     ...                  8.0                 35.0            30.232
# 3     ...                  7.0                 35.0            30.566
# 4     ...                  5.0                 13.0            30.233
# ...   ...                  ...                  ...               ...
# 3898  ...                 90.0                 36.0            29.781
# 3899  ...                 90.0                 40.0             29.93
# 3900  ...                 96.0                 35.0            29.941
# 3901  ...                 94.0                 35.0            29.792
# 3902  ...                 94.0                 35.0            29.792
#
#       Minimum pressure  Maximum windspeed (mph  Maximum gust speed (mph  \
# 0               29.596                    41.4                     59.0
# 1               29.268                    35.7                     51.0
# 2                29.26                    25.3                     38.0
# 3               30.227                    12.7                     20.0
# 4               29.568                    38.0                     53.0
# ...                ...                     ...                      ...
# 3898            29.645                     8.1                     17.3
# 3899            29.745                    11.5                     15.0
# 3900            29.781                    13.8                     18.4
# 3901            29.675                    17.3                     26.5
# 3902            29.675                    17.3                     26.5
#
#       Maximum heat index (°F       Date1  Month         diff_pressure
# 0                       40.0  2022-01-01     01   0.16600000000000037
# 1                       52.0  2022-01-02     01    0.4009999999999998
# 2                       41.0  2022-01-03     01    0.9719999999999978
# 3                       32.0  2022-01-04     01   0.33899999999999864
# 4                       32.0  2022-01-05     01    0.6649999999999991
# ...                      ...         ...    ...                   ...
# 3898                    77.5  2022-07-25     07   0.13599999999999923
# 3899                    77.5  2022-07-26     07   0.18499999999999872
# 3900                    78.2  2022-07-27     07   0.16000000000000014
# 3901                    77.6  2022-07-28     07  0.11700000000000088;
# 3902                    77.6  2022-07-28     07  0.11700000000000088;
#
# [3903 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Date', ' Temperature', ' Average humidity (%', ' Average dewpoint (°F',
#        ' Average barometer (in', ' Average windspeed (mph',
#        ' Average gustspeed (mph', ' Average direction (°deg',
#        ' Rainfall for month (in', 'Rainfall for year (in',
#        ' Maximum rain per minute', ' Maximum temperature (°F',
#        ' Minimum temperature (°F', ' Maximum humidity (%',
#        ' Minimum humidity (%', ' Maximum pressure', ' Minimum pressure',
#        ' Maximum windspeed (mph', ' Maximum gust speed (mph',
#        ' Maximum heat index (°F', 'Date1', ' Month', ' diff_pressure'],
#       dtype='object')

# %%
cols=[ ' Temperature', ' Average humidity (%', ' Average dewpoint (°F',
       ' Average barometer (in', ' Average windspeed (mph',
       ' Average gustspeed (mph', ' Average direction (°deg',
       ' Rainfall for month (in', 'Rainfall for year (in',
       ' Maximum rain per minute', ' Maximum temperature (°F',
       ' Minimum temperature (°F', ' Maximum humidity (%',
       ' Minimum humidity (%', ' Maximum pressure', ' Minimum pressure',
       ' Maximum windspeed (mph', ' Maximum gust speed (mph',
       ' Maximum heat index (°F',  ' Month', ' diff_pressure']

# %% [markdown]
# # Convert datatype to numeric

# %%
for i in  cols:
    df[i] = pd.to_numeric(df[i], errors='coerce')

# %%
df
# Out:
#             Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0     01-01-2022          37.8                  35.0                   12.7
# 1     2022-01-02          43.2                  32.0                   14.7
# 2     2022-01-03          25.7                  60.0                   12.7
# 3     2022-01-04           9.3                  67.0                    0.1
# 4     2022-01-05          23.5                  30.0                   -5.3
# ...          ...           ...                   ...                    ...
# 3898  2022-07-25          62.8                  60.0                   48.1
# 3899  2022-07-26          60.6                  68.0                   48.9
# 3900  2022-07-27          61.7                  64.0                   47.4
# 3901  2022-07-28          60.5                  61.0                   45.3
# 3902  2022-07-28          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# 0                       29.7                     26.4
# 1                       29.5                     12.8
# 2                       29.7                      8.3
# 3                       30.4                      2.9
# 4                       29.9                     16.7
# ...                      ...                      ...
# 3898                    29.7                      2.5
# 3899                    29.8                      1.7
# 3900                    29.9                      2.2
# 3901                    29.7                      4.0
# 3902                    29.7                      4.0
#
#        Average gustspeed (mph   Average direction (°deg  \
# 0                        36.8                     274.0
# 1                        18.0                     240.0
# 2                        12.2                     290.0
# 3                         4.5                      47.0
# 4                        23.1                     265.0
# ...                       ...                       ...
# 3898                      4.0                     242.0
# 3899                      2.9                     357.0
# 3900                      4.0                      66.0
# 3901                      6.2                     248.0
# 3902                      6.2                     248.0
#
#        Rainfall for month (in  Rainfall for year (in  ...  \
# 0                        0.00                   0.00  ...
# 1                        0.00                   0.00  ...
# 2                        0.00                   0.00  ...
# 3                        0.00                   0.00  ...
# 4                        0.00                   0.00  ...
# ...                       ...                    ...  ...
# 3898                     0.33                   4.47  ...
# 3899                     0.33                   4.47  ...
# 3900                     0.33                   4.47  ...
# 3901                     0.35                   4.49  ...
# 3902                     0.35                   4.49  ...
#
#        Maximum humidity (%   Minimum humidity (%   Maximum pressure  \
# 0                      4.0                  27.0             29.762
# 1                      4.0                  16.0             29.669
# 2                      8.0                  35.0             30.232
# 3                      7.0                  35.0             30.566
# 4                      5.0                  13.0             30.233
# ...                    ...                   ...                ...
# 3898                  90.0                  36.0             29.781
# 3899                  90.0                  40.0             29.930
# 3900                  96.0                  35.0             29.941
# 3901                  94.0                  35.0             29.792
# 3902                  94.0                  35.0             29.792
#
#        Minimum pressure   Maximum windspeed (mph   Maximum gust speed (mph  \
# 0                29.596                     41.4                      59.0
# 1                29.268                     35.7                      51.0
# 2                29.260                     25.3                      38.0
# 3                30.227                     12.7                      20.0
# 4                29.568                     38.0                      53.0
# ...                 ...                      ...                       ...
# 3898             29.645                      8.1                      17.3
# 3899             29.745                     11.5                      15.0
# 3900             29.781                     13.8                      18.4
# 3901             29.675                     17.3                      26.5
# 3902             29.675                     17.3                      26.5
#
#        Maximum heat index (°F       Date1   Month   diff_pressure
# 0                        40.0  2022-01-01       1           0.166
# 1                        52.0  2022-01-02       1           0.401
# 2                        41.0  2022-01-03       1           0.972
# 3                        32.0  2022-01-04       1           0.339
# 4                        32.0  2022-01-05       1           0.665
# ...                       ...         ...     ...             ...
# 3898                     77.5  2022-07-25       7           0.136
# 3899                     77.5  2022-07-26       7           0.185
# 3900                     78.2  2022-07-27       7           0.160
# 3901                     77.6  2022-07-28       7             NaN
# 3902                     77.6  2022-07-28       7             NaN
#
# [3903 rows x 23 columns]

# %% [markdown]
# # Subtask 1: Correct years for given data set

# %%
import datetime

# %%
base='2022-01-01'

# %%
df1=pd.DataFrame({'Date1': pd.date_range(base,periods=len(df['Date']))})

# %%
df['Date']=df1['Date1']

# %%
df
# Out:
#            Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0    2022-01-01          37.8                  35.0                   12.7
# 1    2022-01-02          43.2                  32.0                   14.7
# 2    2022-01-03          25.7                  60.0                   12.7
# 3    2022-01-04           9.3                  67.0                    0.1
# 4    2022-01-05          23.5                  30.0                   -5.3
# ...         ...           ...                   ...                    ...
# 3898 2032-09-03          62.8                  60.0                   48.1
# 3899 2032-09-04          60.6                  68.0                   48.9
# 3900 2032-09-05          61.7                  64.0                   47.4
# 3901 2032-09-06          60.5                  61.0                   45.3
# 3902 2032-09-07          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# 0                       29.7                     26.4
# 1                       29.5                     12.8
# 2                       29.7                      8.3
# 3                       30.4                      2.9
# 4                       29.9                     16.7
# ...                      ...                      ...
# 3898                    29.7                      2.5
# 3899                    29.8                      1.7
# 3900                    29.9                      2.2
# 3901                    29.7                      4.0
# 3902                    29.7                      4.0
#
#        Average gustspeed (mph   Average direction (°deg  \
# 0                        36.8                     274.0
# 1                        18.0                     240.0
# 2                        12.2                     290.0
# 3                         4.5                      47.0
# 4                        23.1                     265.0
# ...                       ...                       ...
# 3898                      4.0                     242.0
# 3899                      2.9                     357.0
# 3900                      4.0                      66.0
# 3901                      6.2                     248.0
# 3902                      6.2                     248.0
#
#        Rainfall for month (in  Rainfall for year (in  ...  \
# 0                        0.00                   0.00  ...
# 1                        0.00                   0.00  ...
# 2                        0.00                   0.00  ...
# 3                        0.00                   0.00  ...
# 4                        0.00                   0.00  ...
# ...                       ...                    ...  ...
# 3898                     0.33                   4.47  ...
# 3899                     0.33                   4.47  ...
# 3900                     0.33                   4.47  ...
# 3901                     0.35                   4.49  ...
# 3902                     0.35                   4.49  ...
#
#        Maximum humidity (%   Minimum humidity (%   Maximum pressure  \
# 0                      4.0                  27.0             29.762
# 1                      4.0                  16.0             29.669
# 2                      8.0                  35.0             30.232
# 3                      7.0                  35.0             30.566
# 4                      5.0                  13.0             30.233
# ...                    ...                   ...                ...
# 3898                  90.0                  36.0             29.781
# 3899                  90.0                  40.0             29.930
# 3900                  96.0                  35.0             29.941
# 3901                  94.0                  35.0             29.792
# 3902                  94.0                  35.0             29.792
#
#        Minimum pressure   Maximum windspeed (mph   Maximum gust speed (mph  \
# 0                29.596                     41.4                      59.0
# 1                29.268                     35.7                      51.0
# 2                29.260                     25.3                      38.0
# 3                30.227                     12.7                      20.0
# 4                29.568                     38.0                      53.0
# ...                 ...                      ...                       ...
# 3898             29.645                      8.1                      17.3
# 3899             29.745                     11.5                      15.0
# 3900             29.781                     13.8                      18.4
# 3901             29.675                     17.3                      26.5
# 3902             29.675                     17.3                      26.5
#
#        Maximum heat index (°F       Date1   Month   diff_pressure
# 0                        40.0  2022-01-01       1           0.166
# 1                        52.0  2022-01-02       1           0.401
# 2                        41.0  2022-01-03       1           0.972
# 3                        32.0  2022-01-04       1           0.339
# 4                        32.0  2022-01-05       1           0.665
# ...                       ...         ...     ...             ...
# 3898                     77.5  2022-07-25       7           0.136
# 3899                     77.5  2022-07-26       7           0.185
# 3900                     78.2  2022-07-27       7           0.160
# 3901                     77.6  2022-07-28       7             NaN
# 3902                     77.6  2022-07-28       7             NaN
#
# [3903 rows x 23 columns]

# %% [markdown]
# # Subtask 2: removal of duplicate rows and duplicate Columns

# %%
df.drop(columns=['Date1',' Maximum rain per minute'],inplace=True)

# %%
df[df.duplicated(subset=[ ' Temperature', ' Average humidity (%', ' Average dewpoint (°F',
       ' Average barometer (in', ' Average windspeed (mph',
       ' Average gustspeed (mph', ' Average direction (°deg',
       ' Rainfall for month (in', 'Rainfall for year (in',
     ' Maximum temperature (°F',
       ' Minimum temperature (°F', ' Maximum humidity (%',
       ' Minimum humidity (%', ' Maximum pressure', ' Minimum pressure',
       ' Maximum windspeed (mph', ' Maximum gust speed (mph',
       ' Maximum heat index (°F',  ' diff_pressure'],keep='first')==True]
# Out:
#            Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 3902 2032-09-07          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# 3902                    29.7                      4.0
#
#        Average gustspeed (mph   Average direction (°deg  \
# 3902                      6.2                     248.0
#
#        Rainfall for month (in  Rainfall for year (in  ...  \
# 3902                     0.35                   4.49  ...
#
#        Minimum temperature (°F   Maximum humidity (%   Minimum humidity (%  \
# 3902                      46.0                  94.0                  35.0
#
#        Maximum pressure   Minimum pressure   Maximum windspeed (mph  \
# 3902             29.792             29.675                     17.3
#
#        Maximum gust speed (mph   Maximum heat index (°F   Month  \
# 3902                      26.5                     77.6       7
#
#        diff_pressure
# 3902             NaN
#
# [1 rows x 21 columns]

# %%
df
# Out:
#            Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0    2022-01-01          37.8                  35.0                   12.7
# 1    2022-01-02          43.2                  32.0                   14.7
# 2    2022-01-03          25.7                  60.0                   12.7
# 3    2022-01-04           9.3                  67.0                    0.1
# 4    2022-01-05          23.5                  30.0                   -5.3
# ...         ...           ...                   ...                    ...
# 3898 2032-09-03          62.8                  60.0                   48.1
# 3899 2032-09-04          60.6                  68.0                   48.9
# 3900 2032-09-05          61.7                  64.0                   47.4
# 3901 2032-09-06          60.5                  61.0                   45.3
# 3902 2032-09-07          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# 0                       29.7                     26.4
# 1                       29.5                     12.8
# 2                       29.7                      8.3
# 3                       30.4                      2.9
# 4                       29.9                     16.7
# ...                      ...                      ...
# 3898                    29.7                      2.5
# 3899                    29.8                      1.7
# 3900                    29.9                      2.2
# 3901                    29.7                      4.0
# 3902                    29.7                      4.0
#
#        Average gustspeed (mph   Average direction (°deg  \
# 0                        36.8                     274.0
# 1                        18.0                     240.0
# 2                        12.2                     290.0
# 3                         4.5                      47.0
# 4                        23.1                     265.0
# ...                       ...                       ...
# 3898                      4.0                     242.0
# 3899                      2.9                     357.0
# 3900                      4.0                      66.0
# 3901                      6.2                     248.0
# 3902                      6.2                     248.0
#
#        Rainfall for month (in  Rainfall for year (in  ...  \
# 0                        0.00                   0.00  ...
# 1                        0.00                   0.00  ...
# 2                        0.00                   0.00  ...
# 3                        0.00                   0.00  ...
# 4                        0.00                   0.00  ...
# ...                       ...                    ...  ...
# 3898                     0.33                   4.47  ...
# 3899                     0.33                   4.47  ...
# 3900                     0.33                   4.47  ...
# 3901                     0.35                   4.49  ...
# 3902                     0.35                   4.49  ...
#
#        Minimum temperature (°F   Maximum humidity (%   Minimum humidity (%  \
# 0                         34.0                   4.0                  27.0
# 1                         37.0                   4.0                  16.0
# 2                          6.0                   8.0                  35.0
# 3                         -0.0                   7.0                  35.0
# 4                         15.0                   5.0                  13.0
# ...                        ...                   ...                   ...
# 3898                      55.1                  90.0                  36.0
# 3899                      50.5                  90.0                  40.0
# 3900                      43.6                  96.0                  35.0
# 3901                      46.0                  94.0                  35.0
# 3902                      46.0                  94.0                  35.0
#
#        Maximum pressure   Minimum pressure   Maximum windspeed (mph  \
# 0                29.762             29.596                     41.4
# 1                29.669             29.268                     35.7
# 2                30.232             29.260                     25.3
# 3                30.566             30.227                     12.7
# 4                30.233             29.568                     38.0
# ...                 ...                ...                      ...
# 3898             29.781             29.645                      8.1
# 3899             29.930             29.745                     11.5
# 3900             29.941             29.781                     13.8
# 3901             29.792             29.675                     17.3
# 3902             29.792             29.675                     17.3
#
#        Maximum gust speed (mph   Maximum heat index (°F   Month  \
# 0                         59.0                     40.0       1
# 1                         51.0                     52.0       1
# 2                         38.0                     41.0       1
# 3                         20.0                     32.0       1
# 4                         53.0                     32.0       1
# ...                        ...                      ...     ...
# 3898                      17.3                     77.5       7
# 3899                      15.0                     77.5       7
# 3900                      18.4                     78.2       7
# 3901                      26.5                     77.6       7
# 3902                      26.5                     77.6       7
#
#        diff_pressure
# 0              0.166
# 1              0.401
# 2              0.972
# 3              0.339
# 4              0.665
# ...              ...
# 3898           0.136
# 3899           0.185
# 3900           0.160
# 3901             NaN
# 3902             NaN
#
# [3903 rows x 21 columns]

# %%
df.drop(3902)
# Out:
#            Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0    2022-01-01          37.8                  35.0                   12.7
# 1    2022-01-02          43.2                  32.0                   14.7
# 2    2022-01-03          25.7                  60.0                   12.7
# 3    2022-01-04           9.3                  67.0                    0.1
# 4    2022-01-05          23.5                  30.0                   -5.3
# ...         ...           ...                   ...                    ...
# 3897 2032-09-02          64.1                  62.0                   49.8
# 3898 2032-09-03          62.8                  60.0                   48.1
# 3899 2032-09-04          60.6                  68.0                   48.9
# 3900 2032-09-05          61.7                  64.0                   47.4
# 3901 2032-09-06          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# 0                       29.7                     26.4
# 1                       29.5                     12.8
# 2                       29.7                      8.3
# 3                       30.4                      2.9
# 4                       29.9                     16.7
# ...                      ...                      ...
# 3897                    29.6                      3.6
# 3898                    29.7                      2.5
# 3899                    29.8                      1.7
# 3900                    29.9                      2.2
# 3901                    29.7                      4.0
#
#        Average gustspeed (mph   Average direction (°deg  \
# 0                        36.8                     274.0
# 1                        18.0                     240.0
# 2                        12.2                     290.0
# 3                         4.5                      47.0
# 4                        23.1                     265.0
# ...                       ...                       ...
# 3897                      5.8                     240.0
# 3898                      4.0                     242.0
# 3899                      2.9                     357.0
# 3900                      4.0                      66.0
# 3901                      6.2                     248.0
#
#        Rainfall for month (in  Rainfall for year (in  ...  \
# 0                        0.00                   0.00  ...
# 1                        0.00                   0.00  ...
# 2                        0.00                   0.00  ...
# 3                        0.00                   0.00  ...
# 4                        0.00                   0.00  ...
# ...                       ...                    ...  ...
# 3897                     0.24                   4.38  ...
# 3898                     0.33                   4.47  ...
# 3899                     0.33                   4.47  ...
# 3900                     0.33                   4.47  ...
# 3901                     0.35                   4.49  ...
#
#        Minimum temperature (°F   Maximum humidity (%   Minimum humidity (%  \
# 0                         34.0                   4.0                  27.0
# 1                         37.0                   4.0                  16.0
# 2                          6.0                   8.0                  35.0
# 3                         -0.0                   7.0                  35.0
# 4                         15.0                   5.0                  13.0
# ...                        ...                   ...                   ...
# 3897                      55.3                  86.0                  35.0
# 3898                      55.1                  90.0                  36.0
# 3899                      50.5                  90.0                  40.0
# 3900                      43.6                  96.0                  35.0
# 3901                      46.0                  94.0                  35.0
#
#        Maximum pressure   Minimum pressure   Maximum windspeed (mph  \
# 0                29.762             29.596                     41.4
# 1                29.669             29.268                     35.7
# 2                30.232             29.260                     25.3
# 3                30.566             30.227                     12.7
# 4                30.233             29.568                     38.0
# ...                 ...                ...                      ...
# 3897             29.686             29.577                     15.0
# 3898             29.781             29.645                      8.1
# 3899             29.930             29.745                     11.5
# 3900             29.941             29.781                     13.8
# 3901             29.792             29.675                     17.3
#
#        Maximum gust speed (mph   Maximum heat index (°F   Month  \
# 0                         59.0                     40.0       1
# 1                         51.0                     52.0       1
# 2                         38.0                     41.0       1
# 3                         20.0                     32.0       1
# 4                         53.0                     32.0       1
# ...                        ...                      ...     ...
# 3897                      25.3                     77.4       7
# 3898                      17.3                     77.5       7
# 3899                      15.0                     77.5       7
# 3900                      18.4                     78.2       7
# 3901                      26.5                     77.6       7
#
#        diff_pressure
# 0              0.166
# 1              0.401
# 2              0.972
# 3              0.339
# 4              0.665
# ...              ...
# 3897           0.109
# 3898           0.136
# 3899           0.185
# 3900           0.160
# 3901             NaN
#
# [3902 rows x 21 columns]

# %%
import datetime

# %%
df
# Out:
#             Date   Temperature   Average humidity (%   Average dewpoint (°F  \
# 0     01-01-2022          37.8                  35.0                   12.7
# 1     2022-01-02          43.2                  32.0                   14.7
# 2     2022-01-03          25.7                  60.0                   12.7
# 3     2022-01-04           9.3                  67.0                    0.1
# 4     2022-01-05          23.5                  30.0                   -5.3
# ...          ...           ...                   ...                    ...
# 3898  2022-07-25          62.8                  60.0                   48.1
# 3899  2022-07-26          60.6                  68.0                   48.9
# 3900  2022-07-27          61.7                  64.0                   47.4
# 3901  2022-07-28          60.5                  61.0                   45.3
# 3902  2022-07-28          60.5                  61.0                   45.3
#
#        Average barometer (in   Average windspeed (mph  \
# 0                       29.7                     26.4
# 1                       29.5                     12.8
# 2                       29.7                      8.3
# 3                       30.4                      2.9
# 4                       29.9                     16.7
# ...                      ...                      ...
# 3898                    29.7                      2.5
# 3899                    29.8                      1.7
# 3900                    29.9                      2.2
# 3901                    29.7                      4.0
# 3902                    29.7                      4.0
#
#        Average gustspeed (mph   Average direction (°deg  \
# 0                        36.8                     274.0
# 1                        18.0                     240.0
# 2                        12.2                     290.0
# 3                         4.5                      47.0
# 4                        23.1                     265.0
# ...                       ...                       ...
# 3898                      4.0                     242.0
# 3899                      2.9                     357.0
# 3900                      4.0                      66.0
# 3901                      6.2                     248.0
# 3902                      6.2                     248.0
#
#        Rainfall for month (in  Rainfall for year (in  ...  \
# 0                        0.00                   0.00  ...
# 1                        0.00                   0.00  ...
# 2                        0.00                   0.00  ...
# 3                        0.00                   0.00  ...
# 4                        0.00                   0.00  ...
# ...                       ...                    ...  ...
# 3898                     0.33                   4.47  ...
# 3899                     0.33                   4.47  ...
# 3900                     0.33                   4.47  ...
# 3901                     0.35                   4.49  ...
# 3902                     0.35                   4.49  ...
#
#        Maximum humidity (%   Minimum humidity (%   Maximum pressure  \
# 0                      4.0                  27.0             29.762
# 1                      4.0                  16.0             29.669
# 2                      8.0                  35.0             30.232
# 3                      7.0                  35.0             30.566
# 4                      5.0                  13.0             30.233
# ...                    ...                   ...                ...
# 3898                  90.0                  36.0             29.781
# 3899                  90.0                  40.0             29.930
# 3900                  96.0                  35.0             29.941
# 3901                  94.0                  35.0             29.792
# 3902                  94.0                  35.0             29.792
#
#        Minimum pressure   Maximum windspeed (mph   Maximum gust speed (mph  \
# 0                29.596                     41.4                      59.0
# 1                29.268                     35.7                      51.0
# 2                29.260                     25.3                      38.0
# 3                30.227                     12.7                      20.0
# 4                29.568                     38.0                      53.0
# ...                 ...                      ...                       ...
# 3898             29.645                      8.1                      17.3
# 3899             29.745                     11.5                      15.0
# 3900             29.781                     13.8                      18.4
# 3901             29.675                     17.3                      26.5
# 3902             29.675                     17.3                      26.5
#
#        Maximum heat index (°F       Date1   Month   diff_pressure
# 0                        40.0  2022-01-01       1           0.166
# 1                        52.0  2022-01-02       1           0.401
# 2                        41.0  2022-01-03       1           0.972
# 3                        32.0  2022-01-04       1           0.339
# 4                        32.0  2022-01-05       1           0.665
# ...                       ...         ...     ...             ...
# 3898                     77.5  2022-07-25       7           0.136
# 3899                     77.5  2022-07-26       7           0.185
# 3900                     78.2  2022-07-27       7           0.160
# 3901                     77.6  2022-07-28       7             NaN
# 3902                     77.6  2022-07-28       7             NaN
#
# [3903 rows x 23 columns]

# %% [markdown]
# # Subtask 3: fix a few labels in the given data set

# %%
cols=df.columns.tolist()

# %%
cols
# Out:
# ['Date',
#  ' Temperature',
#  ' Average humidity (%',
#  ' Average dewpoint (°F',
#  ' Average barometer (in',
#  ' Average windspeed (mph',
#  ' Average gustspeed (mph',
#  ' Average direction (°deg',
#  ' Rainfall for month (in',
#  'Rainfall for year (in',
#  ' Maximum temperature (°F',
#  ' Minimum temperature (°F',
#  ' Maximum humidity (%',
#  ' Minimum humidity (%',
#  ' Maximum pressure',
#  ' Minimum pressure',
#  ' Maximum windspeed (mph',
#  ' Maximum gust speed (mph',
#  ' Maximum heat index (°F',
#  ' Month',
#  ' diff_pressure']

# %%
for i,col in enumerate(cols):
    if '(' in col:
        cols[i] = col + ")"
        df.columns= cols

# %%
df.columns
# Out:
# Index(['Date', ' Temperature', ' Average humidity (%)',
#        ' Average dewpoint (°F)', ' Average barometer (in)',
#        ' Average windspeed (mph)', ' Average gustspeed (mph)',
#        ' Average direction (°deg)', ' Rainfall for month (in)',
#        'Rainfall for year (in)', ' Maximum temperature (°F)',
#        ' Minimum temperature (°F)', ' Maximum humidity (%)',
#        ' Minimum humidity (%)', ' Maximum pressure', ' Minimum pressure',
#        ' Maximum windspeed (mph)', ' Maximum gust speed (mph)',
#        ' Maximum heat index (°F)', ' Month', ' diff_pressure'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Date                         0
#  Temperature                 0
#  Average humidity (%)        0
#  Average dewpoint (°F)       0
#  Average barometer (in)      0
#  Average windspeed (mph)     0
#  Average gustspeed (mph)     0
#  Average direction (°deg)    0
#  Rainfall for month (in)     0
# Rainfall for year (in)       0
#  Maximum temperature (°F)    0
#  Minimum temperature (°F)    0
#  Maximum humidity (%)        0
#  Minimum humidity (%)        0
#  Maximum pressure            0
#  Minimum pressure            0
#  Maximum windspeed (mph)     0
#  Maximum gust speed (mph)    0
#  Maximum heat index (°F)     0
#  Month                       0
#  diff_pressure               2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.to_csv("cleaned_file.csv",encoding='utf-8',index=False)
